# %%
# Importing needed librairies 

import pandas as pd
import os
import numpy as np

# %%
df = pd.read_csv('/Users/mac/Downloads/shark.csv', sep=',', engine='python')
df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
df.describe()
# Out:
#               Year  original order
# count  5992.000000     5992.000000
# mean   1925.204606     2997.548899
# std     286.473712     1729.860210
# min       0.000000        2.000000
# 25%    1942.000000     1499.750000
# 50%    1975.000000     2997.500000
# 75%    2003.000000     4495.250000
# max    2016.000000     5993.000000

# %%
table_shark = df.copy()
table_shark = table_shark.drop(table_shark.columns[16:], axis=1)  # df.columns is zero-based pd.Index 
table_shark
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
table_shark.columns=[col.replace(' ', '').lower()  for col in table_shark.columns]
table_shark = table_shark.rename(columns={'casenumber': 'id', 'investigatororsource': 'investigator', 'fatal(y/n)': 'fatalyn'})
table_shark
# Out:
#                 id                                               date  year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
#table_shark.duplicated(subset=None, keep='first')

# %%
table_shark.columns
# Out:
# Index(['id', 'date', 'year', 'type', 'country', 'area', 'location', 'activity',
#        'name', 'sex', 'age', 'injury', 'fatalyn', 'time', 'species',
#        'investigator'],
#       dtype='object')

# %%
#def drop_minor_occurences(dataframe,attribute):
# Out:
# ['USA',
#  'USA',
#  'USA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'USA',
#  'USA',
#  'NEW CALEDONIA',
#  'USA',
#  'AUSTRALIA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'REUNION',
#  'USA',
#  'BAHAMAS',
#  'USA',
#  'USA',
#  'SPAIN',
#  'CHINA',
#  'AUSTRALIA',
#  'USA',
#  'AUSTRALIA',
#  'JAPAN',
#  'AUSTRALIA',
#  'BAHAMAS',
#  'AUSTRALIA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'BAHAMAS',
#  'SPAIN',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'AUSTRALIA',
#  'USA',
#  'USA',
#  'COLUMBIA',
#  'SOUTH AFRICA',
#  'USA',
#  'USA',
#  'USA',
#  'AUSTRALIA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'AUSTRALIA',
#  'EGYPT',
#  'AUSTRALIA',
#  'NEW CALEDONIA',
#  'AUSTRALIA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'NEW ZEALAND',
#  'INDONESIA',
#  'USA',
#  'SOUTH AFRICA',
#  'AUSTRALIA',
#  'FRENCH POLYNESIA',
#  'USA',
#  'NEW CALEDONIA',
#  'CAPE VERDE',
#  'USA',
#  'USA',
#  'USA',
#  'AUSTRALIA',
#  'USA',
# ...

# %%
#table_shark.area.value_counts().plot.bar()

# %%
# Dropping columns with high pencentage of nan values

null_cols = table_shark.isnull().sum()
null_cols
drop_percentage = round(null_cols[null_cols>0]/table_shark.shape[0]*100,2)
drop_percentage
#drop_cols=drop_percentage[drop_percentage>75].index
#drop_cols
# Out:
# Country                    0.72
# Area                       6.71
# Location                   8.28
# Activity                   8.80
# Name                       3.34
# Sex                        9.46
# Age                       44.74
# Injury                     0.45
# Fatal (Y/N)                0.32
# Time                      53.62
# Species                   48.97
# Investigator or Source     0.25
# dtype: float64
