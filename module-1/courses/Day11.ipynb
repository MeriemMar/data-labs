# %%
#https://bit.ly/2HYIkRu
# press cmd + u tohave the source code

# %%
""""Here is the source code


<!DOCTYPE html>
<html>
  <head>
    <title>The HTML5 Breakfast Site</title>
    <meta charset="UTF-8">

    <style>
      body {
        background-color: limegreen;
        margin: 40px;
      } 
    </style>
  </head>
  <body>
    <div id="container"> # to make division into parties inn the body

      <nav id="topnav">
        <a href="https://www.ironhack.com" target="_blank">HOME</a> |
        <a href="https://www.ironhack.com/en/team" target="_blank">ABOUT US</a> |
        <a href="https://www.ironhack.com/en/contact" target="_blank">CONTACT US</a>
      </nav>

      <section id="content">
        <h1>The Ironhack Breakfast Place</h1> # h1 is the header 
        <p>Here you will find all sorts of delicious treats</p> # p is a paragraph, p starts from a new line, no need to push a new line
        <figure>
          <img src="breakfast.jpg" width="400" alt="healthy breakfast">
          <figcaption>CC Image courtesy of Ruth Hartnup on Flickr</figcaption>
        </figure>
      </section>

      <footer>
        <p class="love">Made with love by Ironhack</p>
      </footer>

    </div>
  </body>
</html>"""""

# %%
<b> : bold
<br> new line
structure :  tr td
<tr> row
<td> column
<a> link
<span> small text comme les durées qui apparaissent sur la video

# %%
#cc selecter tester , extension on google chrome

# %%
#click droit sur la page,puis examiner l element, ouvre lapage , utuliser google chrome

# %%
# on trouve des volets, performance, sources  (cliquer sur All)

# %%
#zalando enfant, promos, insepecter, preserve log, clic on delete all (rond barré),clic XHR, passer à la 2ème page, 
#cliquer sur articles?categories..., go to preview , response, 

#headers is the most important part : copy the link on request URL/ IT GIVES THE DATABASE

# %%
#REQUEST mode: get or post

# %%
#status code: if 2xx means the page works normally 
#4xx means we can't access the page (your error)
#5xx means we can't access the page (error of the server

# %%
#we can push in the informations to python via mysql

# %% [markdown]
# # WORK WITH THE JASON FILE

# %%
import json 
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = "https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale"

# %%
response = requests.get(url)
results = response.json()
results
# we need to normalize this output
flat_data = json_normalize(results)
flat_data.articles[0]


flat_data1 = json_normalize(flat_data.articles[0])
flat_data1 = flat_data1.set_index('sku')
flat_data1.brand_name.value_counts()
# Out:
# Nike Sportswear        20
# adidas Originals       12
# Nike Performance        6
# Friboo                  5
# Puma                    5
# Converse                5
# Tommy Hilfiger          3
# Name it                 3
# Polo Ralph Lauren       3
# Vans                    2
# Levi's®                 2
# adidas Performance      2
# Lacoste                 2
# Benetton                2
# New Balance             1
# Champion                1
# Geox                    1
# Jack & Jones Junior     1
# Reebok Classic          1
# OshKosh                 1
# Abercrombie & Fitch     1
# mothercare              1
# Outfit Kids             1
# Petit Bateau            1
# Nike SB                 1
# Birkenstock             1
# Name: brand_name, dtype: int64

# %%
response = requests.get('https://jsonplaceholder.typicode.com/todos')
results = response.json()
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
# ...

# %%
data = pd.DataFrame(results)
data

# %%
flat_data1.family_articles[0]
# Out:
# [{'sku': 'NI116D040-A11',
#   'url_key': 'nike-sportswear-air-max-axis-baskets-basses-ni116d040-a11',
#   'media': [{'path': 'NI/11/6D/04/0A/11/NI116D040-A11@4.jpg',
#     'packet_shot': True,
#     'role': 'FAMILY'}],
#   'name': 'AIR MAX AXIS - Baskets basses - white/monsoon blue',
#   'sizes': ['35.5', '36.5', '37.5', '38', '38.5', '39', '40'],
#   'price': {'original': '84,95\xa0€',
#    'promotional': '68,00\xa0€',
#    'has_different_prices': True,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': True,
#    'has_discount_on_selected_sizes_only': False},
#   'flags': [{'key': 'discountRate',
#     'value': 'Jusqu’à -20%',
#     'tracking_value': 'discount rate'}]},
#  {'sku': 'NI116D040-G11',
#   'url_key': 'nike-sportswear-air-max-axis-baskets-basses-ni116d040-g11',
#   'media': [{'path': 'NI/11/6D/04/0G/11/NI116D040-G11@9.jpg',
#     'packet_shot': True,
#     'role': 'FAMILY'}],
# ...

# %%
response = requests.get('https://api.github.com/events')
results = response.json()
results

data = pd.DataFrame(results)
data
# Out:
#                                                 actor            created_at  \
# 0   {'id': 7010566, 'login': 'unikzforce', 'displa...  2019-05-27T09:38:22Z
# 1   {'id': 109339, 'login': 'freeplant', 'display_...  2019-05-27T09:38:22Z
# 2   {'id': 934260, 'login': 'wing328', 'display_lo...  2019-05-27T09:38:22Z
# 3   {'id': 10884542, 'login': 'MirellaAcero', 'dis...  2019-05-27T09:38:22Z
# 4   {'id': 4880685, 'login': 'wanggn', 'display_lo...  2019-05-27T09:38:22Z
# 5   {'id': 8514816, 'login': 'noname007', 'display...  2019-05-27T09:38:22Z
# 6   {'id': 43034629, 'login': 'hellonk', 'display_...  2019-05-27T09:38:22Z
# 7   {'id': 136472, 'login': 'JorritSalverda', 'dis...  2019-05-27T09:38:22Z
# 8   {'id': 38187276, 'login': 'michaeleby1', 'disp...  2019-05-27T09:38:22Z
# 9   {'id': 979246, 'login': 'c3zi', 'display_login...  2019-05-27T09:38:22Z
# 10  {'id': 44128311, 'login': 'isomorphic-git-test...  2019-05-27T09:38:22Z
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
flat = flatten(data,['actor', 'org', 'payload', 'repo'])
flat.head()
# Out:
#              created_at          id  public        type  \
# 0  2019-05-27T09:38:22Z  9702794433    True  WatchEvent
# 1  2019-05-27T09:38:22Z  9702794428    True   PushEvent
# 2  2019-05-27T09:38:22Z  9702794425    True   PushEvent
# 3  2019-05-27T09:38:22Z  9702794429    True   PushEvent
# 4  2019-05-27T09:38:22Z  9702794423    True   ForkEvent
#
#                                     actor_avatar_url actor_display_login  \
# 0   https://avatars.githubusercontent.com/u/7010566?          unikzforce
# 1    https://avatars.githubusercontent.com/u/109339?           freeplant
# 2    https://avatars.githubusercontent.com/u/934260?             wing328
# 3  https://avatars.githubusercontent.com/u/10884542?        MirellaAcero
# 4   https://avatars.githubusercontent.com/u/4880685?              wanggn
#
#   actor_gravatar_id  actor_id   actor_login  \
# 0                     7010566    unikzforce
# 1                      109339     freeplant
# 2                      934260       wing328
# ...

# %%
flatt = json_normalize(results)
flatt
# Out:
#                                      actor.avatar_url  \
# 0    https://avatars.githubusercontent.com/u/7010566?
# 1     https://avatars.githubusercontent.com/u/109339?
# 2     https://avatars.githubusercontent.com/u/934260?
# 3   https://avatars.githubusercontent.com/u/10884542?
# 4    https://avatars.githubusercontent.com/u/4880685?
# 5    https://avatars.githubusercontent.com/u/8514816?
# 6   https://avatars.githubusercontent.com/u/43034629?
# 7     https://avatars.githubusercontent.com/u/136472?
# 8   https://avatars.githubusercontent.com/u/38187276?
# 9     https://avatars.githubusercontent.com/u/979246?
# 10  https://avatars.githubusercontent.com/u/44128311?
# 11  https://avatars.githubusercontent.com/u/16175139?
# 12  https://avatars.githubusercontent.com/u/51074849?
# 13  https://avatars.githubusercontent.com/u/40306853?
# 14   https://avatars.githubusercontent.com/u/6049367?
# 15   https://avatars.githubusercontent.com/u/8517910?
# ...
