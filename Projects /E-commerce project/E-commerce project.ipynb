# %% [markdown]
# # E-commerce project

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set()

# %%
data=pd.read_csv('data.csv',encoding = 'ISO-8859-1')

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null object
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
#data.InvoiceNo = data.InvoiceNo.astype('int64')

# %%
#Check missing value for each variable 
data.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
data.isnull().sum() / data.shape[0] * 100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %% [markdown]
# 24 % of the customers are unknown

# %%
#data.Description.value_counts()
#data[data['Description'].map(len) < 100]

# %%
plt.figure(figsize = (20, 15))
info = data.Description.value_counts()
plt.hist(info, bins = 50)
plt.show()

# %%
# show the rows with missing values
# check out the rows with missing values
data[data.isnull().any(axis=1)].head()

# %%
# Description - UPPER case to LOWER case
data['Description'] = data.Description.str.lower()

# %%
data['Description']

# %%
data = data.dropna()

# %%
data.shape

# %%
import os
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')

data['Description'] = data['Description'].apply(lambda x: ' '.join([item for item in x.split() if item not in stop]))

# %%
pd.Series([j for i in data.Description.str.lower().str.split() for j in i if re.fullmatch('[a-zA-Z]*',j)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-170-bb6b03a859e6> in <module>
# ----> 1 pd.Series([j for i in data.Description.str.lower().str.split() for j in i if re.fullmatch('[a-zA-Z]*',j)])
#       2
#
# <ipython-input-170-bb6b03a859e6> in <listcomp>(.0)
# ----> 1 pd.Series([j for i in data.Description.str.lower().str.split() for j in i if re.fullmatch('[a-zA-Z]*',j)])
#       2
#
# TypeError: 'float' object is not iterable

# %%
# change the invoice_date format - String to Timestamp format
data['Invoice_Date'] = pd.to_datetime(data.InvoiceDate, format='%m/%d/%Y %H:%M')

# %%
#drop rows with missing values
data = data.dropna()

# %%
# check for missing values
data.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  406829.000000  406829.000000  406829.000000
# mean       12.061303       3.460471   15287.690570
# std       248.693370      69.315162    1713.600303
# min    -80995.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13953.000000
# 50%         5.000000       1.950000   15152.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# remove rows with negative quantities
data = data[data.Quantity > 0]

# %%
data['TotalSales'] = data['Quantity'] * data['UnitPrice']

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  TotalSales
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom       15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom       20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom       22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom       20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom       20.34

# %%
# create some useful features ...
data['day']=data.Invoice_Date.dt.day
data['hour']=data.Invoice_Date.dt.hour
data['month']=data.Invoice_Date.dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-6b36e4070745> in <module>
#       1 # create some useful features ...
# ----> 2 data['day']=data.Invoice_Date.dt.day
#       3 data['hour']=data.Invoice_Date.dt.hour
#       4 data['month']=data.Invoice_Date.dt.month
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Invoice_Date'

# %%
#data.drop(['InvoiceDate'], axis=1, inplace=True)

# %%
#data.head()

# %%
data.groupby(['CustomerID','Country'])['InvoiceNo'].count().nlargest(10)
# Out:
# CustomerID  Country
# 17841.0     United Kingdom    7847
# 14911.0     EIRE              5677
# 14096.0     United Kingdom    5111
# 12748.0     United Kingdom    4596
# 14606.0     United Kingdom    2700
# 15311.0     United Kingdom    2379
# 14646.0     Netherlands       2080
# 13089.0     United Kingdom    1818
# 13263.0     United Kingdom    1677
# 14298.0     United Kingdom    1637
# Name: InvoiceNo, dtype: int64

# %%
data.drop(['Description'], axis=1)
# Out:
#        InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6   12/1/2010 8:26       2.55     17850.0
# 1         536365     71053         6   12/1/2010 8:26       3.39     17850.0
# 2         536365    84406B         8   12/1/2010 8:26       2.75     17850.0
# 3         536365    84029G         6   12/1/2010 8:26       3.39     17850.0
# 4         536365    84029E         6   12/1/2010 8:26       3.39     17850.0
# 5         536365     22752         2   12/1/2010 8:26       7.65     17850.0
# 6         536365     21730         6   12/1/2010 8:26       4.25     17850.0
# 7         536366     22633         6   12/1/2010 8:28       1.85     17850.0
# 8         536366     22632         6   12/1/2010 8:28       1.85     17850.0
# 9         536367     84879        32   12/1/2010 8:34       1.69     13047.0
# 10        536367     22745         6   12/1/2010 8:34       2.10     13047.0
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Feature engineering

sales= data.groupby(by=['CustomerID','Country'], as_index=False)['TotalSales'].sum()

plt.subplots(figsize=(7,8))
plt.plot(sales.CustomerID, sales.TotalSales)
plt.xlabel('Customers ID')
plt.ylabel('Total Sales ($$)')
plt.title('Total sales for different Customers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-168-ae85f40cf5e0> in <module>
#       1 #Feature engineering
#       2
# ----> 3 sales= data.groupby(by=['CustomerID','Country'], as_index=False)['TotalSales'].sum()
#       4
#       5 plt.subplots(figsize=(7,8))
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/base.py in __getitem__(self, key)
#     268         elif not getattr(self, 'as_index', False):
#     269             if key not in self.obj.columns:
# --> 270                 raise KeyError("Column not found: {key}".format(key=key))
#     271             return self._gotitem(key, ndim=2)
#     272
#
# KeyError: 'Column not found: TotalSales'

# %%
data.drop(['Description'], axis=1)
# Out:
#        InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6   12/1/2010 8:26       2.55     17850.0
# 1         536365     71053         6   12/1/2010 8:26       3.39     17850.0
# 2         536365    84406B         8   12/1/2010 8:26       2.75     17850.0
# 3         536365    84029G         6   12/1/2010 8:26       3.39     17850.0
# 4         536365    84029E         6   12/1/2010 8:26       3.39     17850.0
# 5         536365     22752         2   12/1/2010 8:26       7.65     17850.0
# 6         536365     21730         6   12/1/2010 8:26       4.25     17850.0
# 7         536366     22633         6   12/1/2010 8:28       1.85     17850.0
# 8         536366     22632         6   12/1/2010 8:28       1.85     17850.0
# 9         536367     84879        32   12/1/2010 8:34       1.69     13047.0
# 10        536367     22745         6   12/1/2010 8:34       2.10     13047.0
# ...

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)
census_clusters = kmeans.fit(data)
census_clusters.cluster_centers_
census_missing['Cluster'] = census_clusters.fit_predict(census_missing[census_columns])
census_missing.Cluster.value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-175-d86091bf2d7c> in <module>
#       1 from sklearn.cluster import KMeans
#       2 kmeans = KMeans(n_clusters=4)
# ----> 3 census_clusters = kmeans.fit(data)
#       4 census_clusters.cluster_centers_
#       5 census_missing['Cluster'] = census_clusters.fit_predict(census_missing[census_columns])
#
# /anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py in fit(self, X, y, sample_weight)
#     969                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     970                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 971                 return_n_iter=True)
#     972         return self
#     973
#
# ...

# %%
gmm=mixture.GaussianMixture(3,covariance_type='full').fit(X[0])

# %%
data['category'] = data.Description.str.split().str[-1]

print  (data.category.value_counts())
# Out:
# DESIGN            25690
# HOLDER            13690
# RETROSPOT         13105
# BOX               13003
# SIGN              12255
# CASES             10903
# BAG                9751
# SET                9108
# CHRISTMAS          7900
# BOTTLE             7767
# DECORATION         7163
# BUNTING            6239
# MUG                5890
# BOWL               5490
# PINK               5273
# POLKADOT           5134
# LARGE              4824
# RED                4767
# SMALL              4635
# HEART              4523
# CANDLES            4514
# PAISLEY            4333
# WHITE              4175
# COVER              4037
# CARD               3988
# TISSUES            3806
# BLUE               3700
# KIT                3349
# SAUCER             3276
# GREEN              3194
#                   ...
# Missing               1
# FOUND                 1
# check?                1
# 16954                 1
# Classic               1
# 17104                 1
# oops                  1
# ...

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10        536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11        536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %% [markdown]
# # Customers: when & how much they spend.
