# %%
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn import cluster,datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
import numpy as np
n_samples = 1500
X,y = datasets.make_moons(n_samples,noise=0.05)
X = StandardScaler().fit_transform(X)
single = cluster.AgglomerativeClustering(2,linkage='single')

# %%
kmeans = cluster.KMeans(2)
single.fit(X)
kmeans.fit(X)
y1_pred = single.labels_.astype(int)
y2_pred = kmeans.predict(X)
fig,ax = plt.subplots(1,2,figsize=(12,8)) # 1 row 2 columns
colors = np.array(['blue','red'])
ax[0].scatter(X[:,0],X[:,1],c=colors[y1_pred])
ax[1].scatter(X[:,0],X[:,1],c=colors[y2_pred])

# %%
print(silhouette_score(X,y1_pred))
print(silhouette_score(X,y2_pred))
# Out:
# 0.39133784106013064
# 0.49768250935900965

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(4,12))
visualizer.fit(X)
visualizer.poof()

# %%
X,y = datasets.make_classification(n_samples=1000)
plt.scatter(X[:,0],X[:,1])

# %%
model = cluster.KMeans()
visualizer = KElbowVisualizer(model, k=(4,12))
visualizer.fit(X)
visualizer.poof()

# %%
legend_elems = [Line2D([0], [0], color=color, marker='o', linestyle='', label="Predicted Class {}".format(i))
                for i, color in enumerate(colors)]
ax[0].legend(handles=legend_elems, loc='upper right')
ax[1].legend(handles=legend_elems, loc='upper right')

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

X, _ = make_blobs(n_samples=1500, centers=4, cluster_std=1.5)

kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_pred = kmeans.predict(X)

plt.figure(figsize=(6,6))
plt.scatter(X[:, 0], X[:, 1], c=y_pred)

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=50, alpha=0.75)

plt.show()

# %%
from sklearn.datasets import make_blobs
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R

X, _ = make_blobs(n_samples=1500, n_features=4, centers=4, cluster_std=1.5)

X = np.c_[X, 0.5 * np.random.randn(X.shape[0], 1)]

rot = R.from_euler('y', 45, degrees=True)
X = rot.apply(X)

fig = plt.figure(figsize=(8, 8))
ax = fig.gca(projection='3d')

ax.scatter(X[:, 0], X[:, 1], X[:, 2])
ax.set_xlim(-7, 7)
ax.set_ylim(-7, 7)
ax.set_zlim(-7, 7)

ax.view_init(elev=20, azim=65)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-7c45611cdd8c> in <module>
#       8
#       9 rot = R.from_euler('y', 45, degrees=True)
# ---> 10 X = rot.apply(X)
#      11
#      12 fig = plt.figure(figsize=(8, 8))
#
# /anaconda3/lib/python3.7/site-packages/scipy/spatial/transform/rotation.py in apply(self, vectors, inverse)
#    1285         if vectors.ndim > 2 or vectors.shape[-1] != 3:
#    1286             raise ValueError("Expected input of shape (3,) or (P, 3), "
# -> 1287                              "got {}.".format(vectors.shape))
#    1288
#    1289         single_vector = False
#
# ValueError: Expected input of shape (3,) or (P, 3), got (1500, 5).

# %%
from sklearn.manifold import TSNE

X, y = datasets.load_iris(return_X_y=True)
colors=np.array(['black','yellow','green'])
fig, ax = plt.subplots(1, 4, figsize=(15, 7))
for i, perp in enumerate([5, 30, 50, 100]):
    tsne = TSNE(perplexity=perp)
    x_embedded = tsne.fit_transform(X)
    ax[i].scatter(x_embedded[:, 0], x_embedded[:, 1], c=colors[y])
    ax[i].set_title("Perplexity = {}".format(perp))
    
plt.show()

# %%
from sklearn.datasets import make_blobs
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R

X, _ = make_blobs(n_samples=500, n_features=2, centers=3, cluster_std=1.0)

X = np.c_[X, 0.5 * np.random.randn(X.shape[0], 1)]

rot = R.from_euler('y', 45, degrees=True)
X = rot.apply(X)

fig = plt.figure(figsize=(8, 8))
ax = fig.gca(projection='3d')

ax.scatter(X[:, 0], X[:, 1], X[:, 2])
ax.set_xlim(-7, 7)
ax.set_ylim(-7, 7)
ax.set_zlim(-7, 7)

ax.view_init(elev=20, azim=65)
plt.show()
